# %%
l=[[0,'Apple',6,15],[1,'Mango',8,20],[2,'Guava',10,20]]
for i in range(len(l)):
  print(l[i])
print("Enter Quantity")
o=0
cost=0
l1=[]
l2=[]
l3=[]
serialnumber=[0,1,2]
amount=0
i='y'
while i=='y':
  e=int(input('Enter item :'))
  print("If you dont want anything press 0")
  a=int(input(f'How many {l[e][1]} packets you want :'))
  if a<=l[e][2]:
    l1.append(l[e][1])
    l2.append(a)
    cost=a*l[e][3]
    l3.append(cost)
    i=input("Continue y/n : ").lower()
    amount=amount+cost
    l[e][2]=l[e][2]-a
  else:
    print(f'Not Available in stock you can buy only {l[e][2]}:')  
    continue 
print("Items present in your cart")
print("Here is your Cart")
print("%10s %10s %10s %10s" % ("SerialNO","Items","Quantity","Cost/Item"))
for q in range(3):
  print("%10d %10s %10d %10.3f" % (serialnumber[q],l1[q],l2[q],l3[q]))
print(f'Total amount of items in your cart {amount}')
cus=input("Enter your name:")
address=input("Enter address:")

m=int(input('Enter distance from store (Rs10 deliver charge per km)'))
D=m*10
if m<=5:
  print(m*10,'Rs delivery charges')
elif 5<m<=10:
  print(m*10,'Rs delivery charge applied')  
elif 10<m<=20:
  print(m*10,'Rs delivery charges applied')
else:
  print('Delivery not available')  
bill=amount+D
print('---Your Bill ----')  
print("%10s %10s %10s %10s" %("SNo","Items","Quantity","Cost/Item" ))
for j in range(3):
  print("%10d %10s %10d %10.3f" % (serialnumber[j],l1[j],l2[j],l3[j]))
print(' Delivery Charge =',D)
print('----You Have To Pay----')  
print('Total Amount =',bill)
print('----Enjoy Your Day----')
print("Updated Quantity Available: ")
for i in range(len(l)):
  print(l[i])
print("We Hope You Liked Our Service")
# Out:
# [0, 'Apple', 6, 15]
# [1, 'Mango', 8, 20]
# [2, 'Guava', 10, 20]
# Enter Quantity
# Enter item :0
# If you dont want anything press 0
# How many Apple packets you want :8
# Not Available in stock you can buy only 6:
# Enter item :1
# If you dont want anything press 0
# How many Mango packets you want :10
# Not Available in stock you can buy only 8:
# Enter item :2
# If you dont want anything press 0
# How many Guava packets you want :12
# Not Available in stock you can buy only 10:
# Enter item :0
# If you dont want anything press 0
# How many Apple packets you want :2
# Continue y/n : y
# Enter item :1
# If you dont want anything press 0
# How many Mango packets you want :3
# Continue y/n : y
# Enter item :2
# If you dont want anything press 0
# How many Guava packets you want :5
# Continue y/n : n
# Items present in your cart
# Here is your Cart
#   SerialNO      Items   Quantity  Cost/Item
#          0      Apple          2     30.000
#          1      Mango          3     60.000
# ...
